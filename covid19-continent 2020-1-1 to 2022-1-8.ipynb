# %%
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\User\Desktop\py\owid-covid-data.csv")

# %%
data
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1           AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2           AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3           AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4           AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
# ...         ...       ...          ...         ...          ...        ...
# 153167      ZWE    Africa     Zimbabwe  2022-01-04     217678.0     1591.0
# 153168      ZWE    Africa     Zimbabwe  2022-01-05     219057.0     1379.0
# 153169      ZWE    Africa     Zimbabwe  2022-01-06     220178.0     1121.0
# 153170      ZWE    Africa     Zimbabwe  2022-01-07     221282.0     1104.0
# 153171      ZWE    Africa     Zimbabwe  2022-01-08     221918.0      636.0
#
# ...

# %%
data.count()
# Out:
# iso_code                                   153172
# continent                                  143944
# location                                   153172
# date                                       153172
# total_cases                                150522
#                                             ...
# human_development_index                    125712
# excess_mortality_cumulative_absolute         5234
# excess_mortality_cumulative                  5234
# excess_mortality                             5234
# excess_mortality_cumulative_per_million      5234
# Length: 67, dtype: int64

# %%
data.isnull().sum()
# Out:
# iso_code                                        0
# continent                                    9228
# location                                        0
# date                                            0
# total_cases                                  2650
#                                             ...
# human_development_index                     27460
# excess_mortality_cumulative_absolute       147938
# excess_mortality_cumulative                147938
# excess_mortality                           147938
# excess_mortality_cumulative_per_million    147938
# Length: 67, dtype: int64

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
 data.head(2)
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
#
#    female_smokers  male_smokers  handwashing_facilities  \
# 0             NaN           NaN                  37.746
# 1             NaN           NaN                  37.746
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                         0.5            64.83                    0.511
# 1                         0.5            64.83                    0.511
#
#    excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# ...

# %%
data.groupby('continent').sum()
# Out:
#                 total_cases   new_cases  new_cases_smoothed  total_deaths  \
# continent
# Africa         2.593843e+09  10045529.0        9.886533e+06    65860961.0
# Asia           2.247444e+10  85558432.0        8.465005e+07   337959627.0
# Europe         2.106757e+10  96717312.0        9.315243e+07   470835910.0
# North America  1.822898e+10  70534061.0        6.818195e+07   410889747.0
# Oceania        6.893703e+07   1140876.0        8.687798e+05      925814.0
# South America  1.268110e+10  40621020.0        4.009005e+07   398391054.0
#
#                new_deaths  new_deaths_smoothed  total_cases_per_million  \
# continent
# Africa           230064.0           229028.659             2.248172e+08
# Asia            1259965.0          1254561.241             6.281646e+08
# Europe          1552096.0          1543032.589             1.642196e+09
# North America   1231352.0          1225155.658             5.010065e+08
# ...

# %%
data.groupby('continent')['total_deaths'].sum().sort_values(ascending = False)
# Out:
# continent
# Europe           470835910.0
# North America    410889747.0
# South America    398391054.0
# Asia             337959627.0
# Africa            65860961.0
# Oceania             925814.0
# Name: total_deaths, dtype: float64

# %%
data.groupby('continent')['total_cases'].sum().sort_values(ascending = False)
# Out:
# continent
# Asia             2.247444e+10
# Europe           2.106757e+10
# North America    1.822898e+10
# South America    1.268110e+10
# Africa           2.593843e+09
# Oceania          6.893703e+07
# Name: total_cases, dtype: float64

# %%
data.groupby('continent')['male_smokers'].sum().sort_values(ascending = False)
# Out:
# continent
# Asia             1035885.2
# Europe            977548.7
# Africa            656213.2
# North America     182238.9
# Oceania           145147.8
# South America     134997.2
# Name: male_smokers, dtype: float64

# %%
data.groupby('continent')['hospital_beds_per_thousand'].sum().sort_values(ascending = False)
# Out:
# continent
# Europe           152477.501
# Asia              87232.670
# Africa            40085.140
# North America     35792.200
# South America     17143.100
# Oceania           10507.170
# Name: hospital_beds_per_thousand, dtype: float64

# %%
data.groupby('continent')['female_smokers'].sum().sort_values(ascending = False)
# Out:
# continent
# Europe           643883.7
# Asia             125220.2
# Oceania           69210.3
# South America     68035.7
# North America     62267.5
# Africa            61695.6
# Name: female_smokers, dtype: float64
